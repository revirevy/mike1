# %%
#Going to use python's plotting function(s) and then use matPlotLib to make it interactive.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib notebook

# %%
df = pd.DataFrame(np.random.randn(10, 4), columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0 -0.756440 -2.120779 -0.530313  0.693475
# 1  1.363528 -0.115142 -0.631989  0.632545
# 2 -0.579590  0.495896  0.347885  0.360804
# 3 -0.074075 -1.753321  0.962746 -1.846876
# 4  1.872920  1.602139 -0.514575  1.481243
# 5 -0.895961 -0.326837  0.037881 -1.816348
# 6 -1.003455 -0.218346  1.675306 -0.085274
# 7 -1.155639 -0.539408  0.213133  0.046421
# 8  1.548279 -0.360239 -1.145939 -0.942479
# 9  0.328001 -0.603923  0.162511  0.315741

# %%
df.plot.scatter()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-87f61cb1750e> in <module>()
# ----> 1 df.plot.scatter()
#       2 plt.show()
#
# TypeError: scatter() takes at least 3 arguments (1 given)

# %%
df.plot.scatter('A','B')
#df.plot.scatter('A','B', c=df['A'], s=df['B']*120, figsize=(10,10))
#This will adjust color and size relative to the axes you chose
# Out:
# <img src="data:image/png;base64,...">
