# %%
import numpy as np
import scipy as sp
from scipy import stats

data = [175, 183, 146, 134, 149, 153]
print np.mean(data)

oneSample = stats.ttest_1samp(data, 155.5)
#.3f means 3 digits to the right of the decimal. the 'f' is for float
print 'The t-stat is %.3f and the p-value is %3f.' %oneSample
# Out:
# 156.666666667
# The t-stat is 0.154 and the p-value is 0.883885.

# %%
male = [175, 183, 146, 134, 149, 153]
female = [126, 143, 118, 126, 151, 112]
print np.mean(male), np.mean(female)
print np.std(male), np.std(female)

twoSample = stats.ttest_ind(male, female)#here we do 'ind' because they're independent
print 'The t-stat is %.3f and the p-value is %3f.' %twoSample
# Out:
# 156.666666667 129.333333333
# 16.977108771 13.5851225815
# The t-stat is 2.811 and the p-value is 0.019260.

# %%
female = [126, 143, 118, 126, 151, 132]
femaleAfterZumba = [124, 122, 114, 106, 114, 104]

print np.mean(female), np.mean(femaleAfterZumba)
# Out:
# 132.666666667 114.0

# %%
pairedTest = stats.ttest_rel(femaleAfterZumba, female)#here we do 'rel'ated since they're related

print 'The t-stat is %.3f and the p-value is %3f.' %pairedTest

#There is a 10 percent chance(p-value) that their mean weight shifted 2 standard deviations below 
#(t-stat) the original mean by random chance
# Out:
# The t-stat is -3.365 and the p-value is 0.020005.
