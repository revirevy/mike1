# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
from IPython.display import HTML 
HTML('<iframe width="1200" height="800" src=https://public.tableau.com/shared/89ZP7WSS5?:showVizHome=no&:embed=true frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="1200" height="800" src=https://public.tableau.com/shared/89ZP7WSS5?:showVizHome=no&:embed=true frameborder="0" allowfullscreen></iframe>

# %%
from IPython.display import HTML 
HTML('<iframe width="1200" height="800" src=https://public.tableau.com/views/tabMap_0/Timeline?:showVizHome=no&:embed=true frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="1200" height="800" src=https://public.tableau.com/views/tabMap_0/Timeline?:showVizHome=no&:embed=true frameborder="0" allowfullscreen></iframe>

# %%
df = pd.read_csv('../../assets/westnile-assets/data/train.csv')

# %%
sns.distplot(df.NumMosquitos)

# %%
# plt.RcParams(figsize=(20,10))
a = sns.factorplot(
    x='Species',
    y='NumMosquitos',
    data=df, 
    kind='box',
    size=10
)
a.set_xticklabels(rotation=30)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.head(1)
# Out:
#                                                       Address  \
# Date
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                            Species  Block           Street  Trap  \
# Date
# 2007-05-29  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
#
#                        AddressNumberAndStreet  Latitude  Longitude  \
# Date
# 2007-05-29  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991
#
#             AddressAccuracy  NumMosquitos  WnvPresent
# Date
# 2007-05-29                9             1           0

# %%
df07 = df[df.index.year == 2007]

# %%
df07[['NumMosquitos']].resample('D').apply(sum).dropna().plot()

# %%
#Well that's not very helpful with the missing years
a = df['WnvPresent'].resample('W').count()

# %%
a.plot()
